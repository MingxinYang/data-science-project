# %% [markdown]
# ## Data science group project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.feature_selection import RFE

# %%
bus_data = pd.read_csv("Untitled Folder/Bus Card Type.csv")
bus_data.head()
# Out:
#                       contract      Types of passengers   Jul-16   Aug-16  \
# 0  Sydney Metro Bus Contract 1                    Adult  390,433  386,386
# 1  Sydney Metro Bus Contract 1  Adult Single Bus Trip 1      NaN   25,753
# 2  Sydney Metro Bus Contract 1  Adult Single Bus Trip 2      NaN   17,882
# 3  Sydney Metro Bus Contract 1  Adult Single Bus Trip 3      NaN    1,880
# 4  Sydney Metro Bus Contract 1              Child/Youth   62,800   67,010
#
#     Sep-16   Oct-16   Nov-16   Dec-16   Jan-17   Feb-17  ...   Nov-20  \
# 0  370,068  381,402  405,245  353,196  341,332  386,683  ...  278,318
# 1   23,416   23,138   23,352   22,065   21,306   21,277  ...        2
# 2   14,984   14,465   13,914   13,285   12,021   11,824  ...      NaN
# 3    1,459    1,355    1,198    1,102    1,098    1,009  ...      NaN
# 4   70,022   78,951   76,328   77,290   80,779   80,920  ...   41,384
#
#     Dec-20   Jan-21   Feb-21   Mar-21   Apr-21   May-21   Jun-21   Jul-21  \
# 0  261,170  230,528  265,311  294,367  271,849  289,229  259,924  127,354
# 1        3        3        3       10        4        8        8        7
# 2      NaN      NaN      NaN        1        7        2        4        1
# 3      NaN      NaN        3      NaN      NaN      NaN        4      NaN
# 4   47,658   46,574   45,469   42,069   52,658   42,457   34,715   11,205
#
#     Aug-21
# 0  102,883
# 1        6
# 2        4
# 3        2
# 4    6,708
#
# [5 rows x 64 columns]

# %%
bus_data.tail()
# Out:
#                               contract Types of passengers      Jul-16  \
# 599  Outer Sydney Metro Bus Contract 5            Employee       3,156
# 600  Outer Sydney Metro Bus Contract 5         Free Travel         957
# 601  Outer Sydney Metro Bus Contract 5      School Student      45,224
# 602  Outer Sydney Metro Bus Contract 5    Senior/Pensioner     124,570
# 603                        Grand Total               Total  21,198,509
#
#          Aug-16      Sep-16      Oct-16      Nov-16      Dec-16      Jan-17  \
# 599       3,334       3,092       2,864       3,203       3,214       3,003
# 600       1,162       1,061       1,063       1,215       1,388       1,309
# 601     110,239      75,262      71,065      92,417      33,800       5,512
# 602     139,526     137,657     134,642     143,341     135,737     127,356
# 603  25,210,772  23,011,540  23,095,302  24,422,383  20,880,865  19,550,895
#
#          Feb-17  ...      Nov-20      Dec-20      Jan-21      Feb-21  \
# 599       2,871  ...         NaN         NaN         NaN         NaN
# 600       1,127  ...         NaN         NaN         NaN         NaN
# 601      91,284  ...         NaN         NaN         NaN         NaN
# 602     131,825  ...         NaN         NaN         NaN         NaN
# 603  22,534,683  ...  14,809,745  13,391,873  11,567,325  14,964,876
#
#          Mar-21      Apr-21      May-21      Jun-21     Jul-21     Aug-21
# 599         NaN         NaN         NaN         NaN        NaN        NaN
# 600         NaN         NaN         NaN         NaN        NaN        NaN
# 601         NaN         NaN         NaN         NaN        NaN        NaN
# 602         NaN         NaN         NaN         NaN        NaN        NaN
# 603  17,032,074  15,471,111  16,650,452  13,859,329  5,097,116  4,277,052
#
# [5 rows x 64 columns]
