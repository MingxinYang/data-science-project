# %% [markdown]
# ## Data science group project

# %% [markdown]
# Hi this is just test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('files/BusCardType.csv', index_col=0)

# %%
df
# Out:
#                                        Types of passengers      Jul-16  \
# contract
# Sydney Metro Bus Contract 1                          Adult     390,433
# Sydney Metro Bus Contract 1        Adult Single Bus Trip 1         NaN
# Sydney Metro Bus Contract 1        Adult Single Bus Trip 2         NaN
# Sydney Metro Bus Contract 1        Adult Single Bus Trip 3         NaN
# Sydney Metro Bus Contract 1                    Child/Youth      62,800
# ...                                                    ...         ...
# Outer Sydney Metro Bus Contract 5                 Employee       3,156
# Outer Sydney Metro Bus Contract 5              Free Travel         957
# Outer Sydney Metro Bus Contract 5           School Student      45,224
# Outer Sydney Metro Bus Contract 5         Senior/Pensioner     124,570
# Grand Total                                          Total  21,198,509
#
#                                        Aug-16      Sep-16      Oct-16  \
# contract
# ...
